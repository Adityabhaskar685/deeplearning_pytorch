# %% [markdown]
# # VGG16 Convolutional Neural Network for Kaggle's Cats and Dogs Images
#
# Implementation of the VGG-16 [1] architecture for training a dogs vs cats classifier.
#
# - References
#
# [1] Simonyan, K., & Zisserman, A. (2014). Very deep convolutional networks for large-scale image recognition. arXiv preprint arXiv:1409.1556.

# %% [markdown]
# ### Imports

# %%
import time
import os
import numpy as np

import torch
import torch.nn.functional as F
import torch.nn as nn

from torch.utils.data import Dataset, DataLoader
from torchvision import transforms

from PIL import Image
import matplotlib.pyplot as plt

if torch.cuda.is_available():
    torch.backends.cudnn.deterministic = True

# %%
# %matplotlib inline

# %% [markdown]
# ### Settings

# %%
# settings

#device
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# hyperparamter
RANDOM_SEED = 1
LEARNING_RATE = 0.001
NUM_EPOCHS = 100
BATCH_SIZE = 128

#Architecture
NUM_CLASSES = 2

# %% [markdown]
# ### Cata vs Dogs Dataset
#
# The dataset folder consists of two subfolders, train, and test1, which contain the training and test images in jpg format, respectively. Note that the test set examples are unlabeled.

# %%
# !unzip /kaggle/input/dogs-vs-cats/test1.zip 
# !unzip /kaggle/input/dogs-vs-cats/train.zip

# %%
import os

num_train_cats = len([i for i in os.listdir(os.path.join('train')) if i.endswith('.jpg') and i.startswith('cat')])

num_train_dogs = len([i for i in os.listdir(os.path.join('train')) if i.endswith('.jpg') and i.startswith('dog')])

print(f"Training set cats: {num_train_cats}")
print(f"Training set dogs: {num_train_dogs}")
# Out:
# Training set cats: 12500
# Training set dogs: 12500

# %%
img = Image.open(os.path.join('train', 'cat.59.jpg'))
print(np.asarray(img,dtype = np.uint8).shape)
plt.imshow(img);
# Out:
# (331, 464, 3)

# %% [markdown]
# ### Creating Validation and Test subsets
# - move 2500 images from the training folder into a test set folder
# - move 2500 images from the training folder into a validation set folder

# %%
if not os.path.exists('test'):
    os.mkdir('test')
    
if not os.path.exists('valid'):
    os.mkdir('valid')

# %%
for fname in os.listdir('train'):
    if not fname.endswith('.jpg'):
        continue
    _, img_num, _ = fname.split('.')
    filepath = os.path.join('train', fname)
    img_num = int(img_num)
    if img_num > 11249:
        os.rename(filepath,filepath.replace('train', 'test'))
    elif img_num > 9999:
        os.rename(filepath,filepath.replace('train', 'valid'))

# %%
len(os.listdir('test')), len(os.listdir('valid'))
# Out:
# (2500, 2500)

# %% [markdown]
# ### Standardizing Images
#
# Getting mean and standard deviation for normalizing via z-score normalization.

# %%
class CatsDogsDataset(Dataset):
    """Custom Dataset for loading CelebA face images"""
    
    def __init__(self, img_dir, transform = None):
        self.img_dir = img_dir
        self.img_names = [i for i in os.listdir(img_dir) if i.endswith('.jpg')]
        
        self.y = []
        for i in self.img_names:
            if i.split(".")[0] == 'cat':
                self.y.append(0)
            else:
                self.y.append(1)
                
                
        self.transform = transform
        
        
    def __getitem__(self, index):
        img = Image.open(os.path.join(self.img_dir, self.img_names[index]))
        
        if self.transform is not None:
            img = self.transform(img)
        
        label = self.y[index]
        return img, label
    
    def __len__(self):
        return len(self.y)
    
custom_transform1 = transforms.Compose([transforms.Resize([64,64]),
                                      transforms.ToTensor()])
train_dataset = CatsDogsDataset(img_dir = os.path.join('train'),
                               transform = custom_transform1)

train_loader = DataLoader(dataset = train_dataset,
                         batch_size= 5000,
                         shuffle = False)


train_mean = []
train_std = []

for i, image in enumerate(train_loader, 0):
    numpy_image = image[0].numpy()
    
    batch_mean = np.mean(numpy_image, axis=(0, 2, 3))
    batch_std = np.std(numpy_image, axis=(0, 2, 3))
    
    train_mean.append(batch_mean)
    train_std.append(batch_std)

train_mean = torch.tensor(np.mean(train_mean, axis=0))
train_std = torch.tensor(np.mean(train_std, axis=0))

print('Mean:', train_mean)
print('Std Dev:', train_std)
# Out:
# Mean: tensor([0.4875, 0.4544, 0.4164])
# Std Dev: tensor([0.2521, 0.2453, 0.2481])

# %% [markdown]
# ### DataLoaders

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomRotation(5),
        transforms.RandomHorizontalFlip(),
        transforms.RandomResizedCrop(64,scale =(0.95,1.0),ratio = (0.95, 1.05)),
        transforms.ToTensor(),
        transforms.Normalize(train_mean, train_std)
        
    ]),
    "valid": transforms.Compose([
        transforms.Resize([64,64]),
        transforms.ToTensor(),
        transforms.Normalize(train_mean, train_std)
    ])
}

train_dataset = CatsDogsDataset(img_dir = os.path.join('train'),
                               transform = data_transforms['train'])

train_loader = DataLoader(dataset = train_dataset,
                         batch_size = BATCH_SIZE,
                         drop_last = True,
                         shuffle = True)


valid_dataset = CatsDogsDataset(img_dir = os.path.join('valid'),
                               transform = data_transforms['valid'])

valid_loader = DataLoader(dataset = valid_dataset,
                         batch_size = BATCH_SIZE,
                         shuffle = False)

test_dataset = CatsDogsDataset(img_dir = os.path.join('test'),
                              transform = data_transforms['valid'])

test_loader = DataLoader(dataset = test_dataset,
                        batch_size = BATCH_SIZE,
                        shuffle = False)

# %% [markdown]
# ### MODEL

# %%
class VGG16(torch.nn.Module):
    
    def __init__(self, num_classes):
        super(VGG16, self).__init__()
        
        #calulate same padding
        # (w-k + 2* p)/ s + 1 = o
        # => p = (s(o-1) - w + k) / 2
        
        self.block_1 = nn.Sequential(
            nn.Conv2d(in_channels = 3,
                     out_channels = 64,
                     kernel_size = (3,3),
                     stride = (1,1),
                     # (1(32-1) - 32 + 3) / 2 = 1
                     padding = 1),
            nn.ReLU(),
            nn.Conv2d(in_channels = 64,
                      out_channels = 64,
                      kernel_size = (3,3),
                      stride = (1,1),
                      padding = 1
                     ),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = (2,2),
                         stride = (2,2)
                        )
            
        )
        
        self.block_2 = nn.Sequential(
            nn.Conv2d(in_channels = 64,
                     out_channels = 128,
                     kernel_size = (3,3),
                     stride = (1,1),
                     padding = 1),
            
            nn.ReLU(),
            nn.Conv2d(in_channels = 128,
                     out_channels = 128,
                     kernel_size = (3,3),
                     stride = (1,1),
                     padding = 1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = (2,2),
                        stride = (2,2))
        )
        
        self.block_3 = nn.Sequential(
            nn.Conv2d(in_channels = 128,
                     out_channels = 256,
                     kernel_size = (3,3),
                     stride = (1,1),
                     padding = 1),
            nn.ReLU(),
            nn.Conv2d(in_channels = 256,
                     out_channels = 256,
                     kernel_size = (3,3),
                     stride = (1,1),
                     padding = 1),
            nn.ReLU(),
            nn.Conv2d(in_channels = 256,
                     out_channels = 256,
                     kernel_size = (3,3),
                     stride = (1,1),
                     padding = 1),
            nn.ReLU(),
            nn.Conv2d(in_channels = 256,
                     out_channels = 256,
                     kernel_size = (3,3),
                     stride = (1,1),
                     padding = 1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = (2,2),
                        stride = (2,2))
        )
        
        self.block_4 = nn.Sequential(
            nn.Conv2d(in_channels = 256,
                     out_channels = 512,
                     kernel_size = (3,3),
                     stride = (1,1),
                     padding = 1),
            nn.ReLU(),
            nn.Conv2d(in_channels = 512,
                     out_channels = 512,
                     kernel_size = (3,3),
                     stride = (1,1),
                     padding = 1),
            nn.ReLU(),
            nn.Conv2d(in_channels = 512,
                     out_channels = 512,
                     kernel_size = (3,3),
                     stride = (1,1),
                     padding = 1),
            nn.ReLU(),
            nn.Conv2d(in_channels = 512,
                     out_channels = 512,
                     kernel_size = (3,3),
                     stride = (1,1),
                     padding = 1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = (2,2),
                        stride = (2,2))
            
        )
        
        self.block_5 = nn.Sequential(
            nn.Conv2d(in_channels = 512,
                     out_channels = 512,
                     kernel_size = (3,3),
                     stride = (1,1),
                     padding = 1),
            nn.ReLU(),
            nn.Conv2d(in_channels = 512,
                     out_channels = 512,
                     kernel_size = (3,3),
                     stride = (1,1),
                     padding = 1),
            nn.ReLU(),
            nn.Conv2d(in_channels = 512,
                     out_channels = 512,
                     kernel_size = (3,3),
                     stride = (1,1),
                     padding = 1),
            nn.ReLU(),
            nn.Conv2d(in_channels = 512,
                     out_channels = 512,
                     kernel_size = (3,3),
                     stride = (1,1),
                     padding = 1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = (2,2),
                        stride = (2,2))
            
            
        )
        
        self.classifier = nn.Sequential(
            nn.Linear(512*2*2, 4096),
            nn.ReLU(),
            nn.Linear(4096,4096),
            nn.ReLU(),
            nn.Linear(4096,num_classes)
        )
        
        for m in self.modules():
            if isinstance(m, torch.nn.Conv2d):
                m.weight.detach().normal_(0,0.05)
                if m.bias is not None:
                    m.bias.detach().zero_()
            elif isinstance(m, torch.nn.Linear):
                m.weight.detach().normal_(0,0.05)
                m.bias.detach().detach().zero_()
                
                
    def forward(self,x):
        x = self.block_1(x)
        x = self.block_2(x)
        x = self.block_3(x)
        x = self.block_4(x)
        x = self.block_5(x)
        
        logits = self.classifier(x.view(-1,512*2*2))
        probas = F.softmax(logits, dim = 1)
        return logits, probas

# %%
torch.manual_seed(RANDOM_SEED)
model = VGG16(num_classes=NUM_CLASSES)

model = model.to(DEVICE)

optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

# %%
model
# Out:
# VGG16(
#   (block_1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (block_2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (block_3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (block_4): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (block_5): Sequential(
#     (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=2048, out_features=4096, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=4096, out_features=4096, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=4096, out_features=2, bias=True)
#   )
# )

# %% [markdown]
# ### Training

# %%
def compute_accuracy_and_loss(model, data_loader, device):
    correct_pred, num_examples = 0, 0
    cross_entropy = 0.
    for i, (features, targets) in enumerate(data_loader):
            
        features = features.to(device)
        targets = targets.to(device)

        logits, probas = model(features)
        cross_entropy += F.cross_entropy(logits, targets).item()
        _, predicted_labels = torch.max(probas, 1)
        num_examples += targets.size(0)
        correct_pred += (predicted_labels == targets).sum()
    return correct_pred.float()/num_examples * 100, cross_entropy/num_examples
    

start_time = time.time()
train_acc_lst, valid_acc_lst = [], []
train_loss_lst, valid_loss_lst = [], []

for epoch in range(NUM_EPOCHS):
    
    model.train()
    for batch_idx, (features, targets) in enumerate(train_loader):
    
        ### PREPARE MINIBATCH
        features = features.to(DEVICE)
        targets = targets.to(DEVICE)
            
        ### FORWARD AND BACK PROP
        logits, probas = model(features)
        cost = F.cross_entropy(logits, targets)
        optimizer.zero_grad()
        
        cost.backward()
        
        ### UPDATE MODEL PARAMETERS
        optimizer.step()
        
        ### LOGGING
        if not batch_idx % 120:
            print (f'Epoch: {epoch+1:03d}/{NUM_EPOCHS:03d} | '
                   f'Batch {batch_idx:03d}/{len(train_loader):03d} |' 
                   f' Cost: {cost:.4f}')
    # no need to build the computation graph for backprop when computing accuracy
    model.eval()
    with torch.set_grad_enabled(False):
        train_acc, train_loss = compute_accuracy_and_loss(model, train_loader, device=DEVICE)
        valid_acc, valid_loss = compute_accuracy_and_loss(model, valid_loader, device=DEVICE)
        train_acc_lst.append(train_acc)
        valid_acc_lst.append(valid_acc)
        train_loss_lst.append(train_loss)
        valid_loss_lst.append(valid_loss)
        print(f'Epoch: {epoch+1:03d}/{NUM_EPOCHS:03d} Train Acc.: {train_acc:.2f}%'
              f' | Validation Acc.: {valid_acc:.2f}%')
        
    elapsed = (time.time() - start_time)/60
    print(f'Time elapsed: {elapsed:.2f} min')
    
    
elapsed = (time.time() - start_time)/60
print(f'Total Training Time: {elapsed:.2f} min')
# Out:
# Epoch: 001/100 | Batch 000/156 | Cost: 1227.5419
# Epoch: 001/100 | Batch 120/156 | Cost: 0.7307
# Epoch: 001/100 Train Acc.: 60.35% | Validation Acc.: 59.96%
# Time elapsed: 2.35 min
# Epoch: 002/100 | Batch 000/156 | Cost: 0.6654
# Epoch: 002/100 | Batch 120/156 | Cost: 0.6391
# Epoch: 002/100 Train Acc.: 65.20% | Validation Acc.: 63.92%
# Time elapsed: 4.62 min
# Epoch: 003/100 | Batch 000/156 | Cost: 0.5962
# Epoch: 003/100 | Batch 120/156 | Cost: 0.6181
# Epoch: 003/100 Train Acc.: 67.26% | Validation Acc.: 65.64%
# Time elapsed: 6.90 min
# Epoch: 004/100 | Batch 000/156 | Cost: 0.6304
# Epoch: 004/100 | Batch 120/156 | Cost: 0.6644
# Epoch: 004/100 Train Acc.: 67.04% | Validation Acc.: 65.64%
# Time elapsed: 9.19 min
# Epoch: 005/100 | Batch 000/156 | Cost: 0.6093
# Epoch: 005/100 | Batch 120/156 | Cost: 0.6131
# Epoch: 005/100 Train Acc.: 66.78% | Validation Acc.: 67.24%
# Time elapsed: 11.48 min
# Epoch: 006/100 | Batch 000/156 | Cost: 0.5939
# Epoch: 006/100 | Batch 120/156 | Cost: 0.7341
# Epoch: 006/100 Train Acc.: 69.08% | Validation Acc.: 68.92%
# Time elapsed: 13.75 min
# Epoch: 007/100 | Batch 000/156 | Cost: 0.6137
# Epoch: 007/100 | Batch 120/156 | Cost: 0.5349
# Epoch: 007/100 Train Acc.: 69.19% | Validation Acc.: 68.84%
# Time elapsed: 16.00 min
# Epoch: 008/100 | Batch 000/156 | Cost: 0.5711
# Epoch: 008/100 | Batch 120/156 | Cost: 0.5711
# Epoch: 008/100 Train Acc.: 69.29% | Validation Acc.: 70.36%
# Time elapsed: 18.26 min
# Epoch: 009/100 | Batch 000/156 | Cost: 0.6558
# Epoch: 009/100 | Batch 120/156 | Cost: 0.5735
# Epoch: 009/100 Train Acc.: 69.61% | Validation Acc.: 69.72%
# Time elapsed: 20.53 min
# Epoch: 010/100 | Batch 000/156 | Cost: 0.6111
# Epoch: 010/100 | Batch 120/156 | Cost: 0.5644
# Epoch: 010/100 Train Acc.: 70.46% | Validation Acc.: 70.00%
# Time elapsed: 22.80 min
# Epoch: 011/100 | Batch 000/156 | Cost: 0.5552
# Epoch: 011/100 | Batch 120/156 | Cost: 0.5885
# Epoch: 011/100 Train Acc.: 71.29% | Validation Acc.: 70.48%
# Time elapsed: 25.05 min
# Epoch: 012/100 | Batch 000/156 | Cost: 0.5235
# Epoch: 012/100 | Batch 120/156 | Cost: 0.5053
# Epoch: 012/100 Train Acc.: 72.05% | Validation Acc.: 72.32%
# Time elapsed: 27.31 min
# Epoch: 013/100 | Batch 000/156 | Cost: 0.5328
# Epoch: 013/100 | Batch 120/156 | Cost: 0.6024
# Epoch: 013/100 Train Acc.: 73.25% | Validation Acc.: 70.00%
# Time elapsed: 29.57 min
# Epoch: 014/100 | Batch 000/156 | Cost: 0.5538
# Epoch: 014/100 | Batch 120/156 | Cost: 0.6222
# Epoch: 014/100 Train Acc.: 72.94% | Validation Acc.: 70.60%
# Time elapsed: 31.82 min
# Epoch: 015/100 | Batch 000/156 | Cost: 0.6174
# Epoch: 015/100 | Batch 120/156 | Cost: 0.6223
# Epoch: 015/100 Train Acc.: 74.84% | Validation Acc.: 72.84%
# Time elapsed: 34.07 min
# Epoch: 016/100 | Batch 000/156 | Cost: 0.5156
# Epoch: 016/100 | Batch 120/156 | Cost: 0.5026
# Epoch: 016/100 Train Acc.: 74.71% | Validation Acc.: 71.84%
# Time elapsed: 36.30 min
# Epoch: 017/100 | Batch 000/156 | Cost: 0.5313
# Epoch: 017/100 | Batch 120/156 | Cost: 0.5004
# Epoch: 017/100 Train Acc.: 76.09% | Validation Acc.: 74.64%
# Time elapsed: 38.54 min
# Epoch: 018/100 | Batch 000/156 | Cost: 0.5153
# Epoch: 018/100 | Batch 120/156 | Cost: 0.4974
# Epoch: 018/100 Train Acc.: 76.63% | Validation Acc.: 76.16%
# Time elapsed: 40.79 min
# Epoch: 019/100 | Batch 000/156 | Cost: 0.4104
# Epoch: 019/100 | Batch 120/156 | Cost: 0.5471
# Epoch: 019/100 Train Acc.: 77.38% | Validation Acc.: 75.16%
# Time elapsed: 43.03 min
# Epoch: 020/100 | Batch 000/156 | Cost: 0.4393
# Epoch: 020/100 | Batch 120/156 | Cost: 0.5166
# Epoch: 020/100 Train Acc.: 77.10% | Validation Acc.: 74.00%
# Time elapsed: 45.25 min
# Epoch: 021/100 | Batch 000/156 | Cost: 0.4885
# Epoch: 021/100 | Batch 120/156 | Cost: 0.4823
# Epoch: 021/100 Train Acc.: 78.45% | Validation Acc.: 76.32%
# Time elapsed: 47.47 min
# Epoch: 022/100 | Batch 000/156 | Cost: 0.4124
# Epoch: 022/100 | Batch 120/156 | Cost: 0.4924
# Epoch: 022/100 Train Acc.: 76.60% | Validation Acc.: 73.76%
# Time elapsed: 49.69 min
# Epoch: 023/100 | Batch 000/156 | Cost: 0.4648
# Epoch: 023/100 | Batch 120/156 | Cost: 0.5344
# Epoch: 023/100 Train Acc.: 78.09% | Validation Acc.: 76.16%
# Time elapsed: 51.93 min
# Epoch: 024/100 | Batch 000/156 | Cost: 0.4466
# Epoch: 024/100 | Batch 120/156 | Cost: 0.4141
# Epoch: 024/100 Train Acc.: 76.62% | Validation Acc.: 72.08%
# Time elapsed: 54.16 min
# Epoch: 025/100 | Batch 000/156 | Cost: 0.4974
# Epoch: 025/100 | Batch 120/156 | Cost: 0.3706
# Epoch: 025/100 Train Acc.: 78.77% | Validation Acc.: 77.24%
# Time elapsed: 56.38 min
# Epoch: 026/100 | Batch 000/156 | Cost: 0.4229
# Epoch: 026/100 | Batch 120/156 | Cost: 0.4243
# Epoch: 026/100 Train Acc.: 80.31% | Validation Acc.: 77.64%
# Time elapsed: 58.62 min
# Epoch: 027/100 | Batch 000/156 | Cost: 0.5015
# Epoch: 027/100 | Batch 120/156 | Cost: 0.4294
# Epoch: 027/100 Train Acc.: 79.36% | Validation Acc.: 78.80%
# Time elapsed: 60.86 min
# Epoch: 028/100 | Batch 000/156 | Cost: 0.5511
# Epoch: 028/100 | Batch 120/156 | Cost: 0.4648
# Epoch: 028/100 Train Acc.: 78.05% | Validation Acc.: 73.88%
# Time elapsed: 63.10 min
# Epoch: 029/100 | Batch 000/156 | Cost: 0.4865
# Epoch: 029/100 | Batch 120/156 | Cost: 0.3980
# Epoch: 029/100 Train Acc.: 81.92% | Validation Acc.: 77.92%
# Time elapsed: 65.32 min
# Epoch: 030/100 | Batch 000/156 | Cost: 0.4436
# Epoch: 030/100 | Batch 120/156 | Cost: 0.3352
# Epoch: 030/100 Train Acc.: 82.39% | Validation Acc.: 79.60%
# Time elapsed: 67.55 min
# Epoch: 031/100 | Batch 000/156 | Cost: 0.3864
# Epoch: 031/100 | Batch 120/156 | Cost: 0.3560
# Epoch: 031/100 Train Acc.: 83.08% | Validation Acc.: 79.56%
# Time elapsed: 69.79 min
# Epoch: 032/100 | Batch 000/156 | Cost: 0.3462
# Epoch: 032/100 | Batch 120/156 | Cost: 0.3313
# Epoch: 032/100 Train Acc.: 83.39% | Validation Acc.: 79.52%
# Time elapsed: 72.06 min
# Epoch: 033/100 | Batch 000/156 | Cost: 0.2905
# Epoch: 033/100 | Batch 120/156 | Cost: 0.4661
# Epoch: 033/100 Train Acc.: 83.93% | Validation Acc.: 79.24%
# Time elapsed: 74.30 min
# Epoch: 034/100 | Batch 000/156 | Cost: 0.3680
# Epoch: 034/100 | Batch 120/156 | Cost: 0.3882
# Epoch: 034/100 Train Acc.: 84.25% | Validation Acc.: 78.96%
# Time elapsed: 76.55 min
# Epoch: 035/100 | Batch 000/156 | Cost: 0.3922
# Epoch: 035/100 | Batch 120/156 | Cost: 0.3545
# Epoch: 035/100 Train Acc.: 83.13% | Validation Acc.: 78.24%
# Time elapsed: 78.80 min
# Epoch: 036/100 | Batch 000/156 | Cost: 0.4110
# Epoch: 036/100 | Batch 120/156 | Cost: 0.3439
# Epoch: 036/100 Train Acc.: 84.23% | Validation Acc.: 78.68%
# Time elapsed: 81.05 min
# Epoch: 037/100 | Batch 000/156 | Cost: 0.3067
# Epoch: 037/100 | Batch 120/156 | Cost: 0.4077
# Epoch: 037/100 Train Acc.: 84.30% | Validation Acc.: 81.00%
# Time elapsed: 83.29 min
# Epoch: 038/100 | Batch 000/156 | Cost: 0.3270
# Epoch: 038/100 | Batch 120/156 | Cost: 0.3433
# Epoch: 038/100 Train Acc.: 85.24% | Validation Acc.: 80.24%
# Time elapsed: 85.51 min
# Epoch: 039/100 | Batch 000/156 | Cost: 0.2998
# Epoch: 039/100 | Batch 120/156 | Cost: 0.2873
# Epoch: 039/100 Train Acc.: 86.30% | Validation Acc.: 81.40%
# Time elapsed: 87.73 min
# Epoch: 040/100 | Batch 000/156 | Cost: 0.3590
# Epoch: 040/100 | Batch 120/156 | Cost: 0.3269
# Epoch: 040/100 Train Acc.: 86.08% | Validation Acc.: 81.16%
# Time elapsed: 89.99 min
# Epoch: 041/100 | Batch 000/156 | Cost: 0.4047
# Epoch: 041/100 | Batch 120/156 | Cost: 0.3178
# Epoch: 041/100 Train Acc.: 86.24% | Validation Acc.: 79.24%
# Time elapsed: 92.25 min
# Epoch: 042/100 | Batch 000/156 | Cost: 0.3099
# Epoch: 042/100 | Batch 120/156 | Cost: 0.2929
# Epoch: 042/100 Train Acc.: 86.14% | Validation Acc.: 81.88%
# Time elapsed: 94.48 min
# Epoch: 043/100 | Batch 000/156 | Cost: 0.2698
# Epoch: 043/100 | Batch 120/156 | Cost: 0.2678
# Epoch: 043/100 Train Acc.: 87.19% | Validation Acc.: 83.24%
# Time elapsed: 96.73 min
# Epoch: 044/100 | Batch 000/156 | Cost: 0.2452
# Epoch: 044/100 | Batch 120/156 | Cost: 0.3589
# Epoch: 044/100 Train Acc.: 83.48% | Validation Acc.: 79.88%
# Time elapsed: 98.97 min
# Epoch: 045/100 | Batch 000/156 | Cost: 0.3810
# Epoch: 045/100 | Batch 120/156 | Cost: 0.2549
# Epoch: 045/100 Train Acc.: 88.52% | Validation Acc.: 80.84%
# Time elapsed: 101.22 min
# Epoch: 046/100 | Batch 000/156 | Cost: 0.2767
# Epoch: 046/100 | Batch 120/156 | Cost: 0.3257
# Epoch: 046/100 Train Acc.: 87.88% | Validation Acc.: 82.68%
# Time elapsed: 103.46 min
# Epoch: 047/100 | Batch 000/156 | Cost: 0.2285
# Epoch: 047/100 | Batch 120/156 | Cost: 0.3100
# Epoch: 047/100 Train Acc.: 88.99% | Validation Acc.: 82.96%
# Time elapsed: 105.71 min
# Epoch: 048/100 | Batch 000/156 | Cost: 0.1977
# Epoch: 048/100 | Batch 120/156 | Cost: 0.3421
# Epoch: 048/100 Train Acc.: 88.52% | Validation Acc.: 83.00%
# Time elapsed: 107.94 min
# Epoch: 049/100 | Batch 000/156 | Cost: 0.3263
# Epoch: 049/100 | Batch 120/156 | Cost: 0.3068
# Epoch: 049/100 Train Acc.: 90.42% | Validation Acc.: 83.20%
# Time elapsed: 110.17 min
# Epoch: 050/100 | Batch 000/156 | Cost: 0.1988
# Epoch: 050/100 | Batch 120/156 | Cost: 0.2375
# Epoch: 050/100 Train Acc.: 90.48% | Validation Acc.: 83.16%
# Time elapsed: 112.40 min
# Epoch: 051/100 | Batch 000/156 | Cost: 0.2183
# Epoch: 051/100 | Batch 120/156 | Cost: 0.3303
# Epoch: 051/100 Train Acc.: 90.05% | Validation Acc.: 83.68%
# Time elapsed: 114.65 min
# Epoch: 052/100 | Batch 000/156 | Cost: 0.2113
# Epoch: 052/100 | Batch 120/156 | Cost: 0.2564
# Epoch: 052/100 Train Acc.: 90.40% | Validation Acc.: 85.00%
# Time elapsed: 116.90 min
# Epoch: 053/100 | Batch 000/156 | Cost: 0.1791
# Epoch: 053/100 | Batch 120/156 | Cost: 0.2386
# Epoch: 053/100 Train Acc.: 90.89% | Validation Acc.: 82.40%
# Time elapsed: 119.15 min
# Epoch: 054/100 | Batch 000/156 | Cost: 0.2630
# Epoch: 054/100 | Batch 120/156 | Cost: 0.2103
# Epoch: 054/100 Train Acc.: 87.46% | Validation Acc.: 79.56%
# Time elapsed: 121.40 min
# Epoch: 055/100 | Batch 000/156 | Cost: 0.2810
# Epoch: 055/100 | Batch 120/156 | Cost: 0.2533
# Epoch: 055/100 Train Acc.: 90.50% | Validation Acc.: 84.76%
# Time elapsed: 123.65 min
# Epoch: 056/100 | Batch 000/156 | Cost: 0.2335
# Epoch: 056/100 | Batch 120/156 | Cost: 0.1503
# Epoch: 056/100 Train Acc.: 91.78% | Validation Acc.: 84.12%
# Time elapsed: 125.89 min
# Epoch: 057/100 | Batch 000/156 | Cost: 0.1197
# Epoch: 057/100 | Batch 120/156 | Cost: 0.1762
# Epoch: 057/100 Train Acc.: 91.61% | Validation Acc.: 84.28%
# Time elapsed: 128.14 min
# Epoch: 058/100 | Batch 000/156 | Cost: 0.1493
# Epoch: 058/100 | Batch 120/156 | Cost: 0.2612
# Epoch: 058/100 Train Acc.: 90.12% | Validation Acc.: 83.40%
# Time elapsed: 130.39 min
# Epoch: 059/100 | Batch 000/156 | Cost: 0.1918
# Epoch: 059/100 | Batch 120/156 | Cost: 0.1784
# Epoch: 059/100 Train Acc.: 91.65% | Validation Acc.: 85.04%
# Time elapsed: 132.65 min
# Epoch: 060/100 | Batch 000/156 | Cost: 0.2268
# Epoch: 060/100 | Batch 120/156 | Cost: 0.2066
# Epoch: 060/100 Train Acc.: 91.66% | Validation Acc.: 84.00%
# Time elapsed: 134.90 min
# Epoch: 061/100 | Batch 000/156 | Cost: 0.2245
# Epoch: 061/100 | Batch 120/156 | Cost: 0.2593
# Epoch: 061/100 Train Acc.: 92.98% | Validation Acc.: 85.08%
# Time elapsed: 137.16 min
# Epoch: 062/100 | Batch 000/156 | Cost: 0.1701
# Epoch: 062/100 | Batch 120/156 | Cost: 0.2228
# Epoch: 062/100 Train Acc.: 91.56% | Validation Acc.: 85.36%
# Time elapsed: 139.41 min
# Epoch: 063/100 | Batch 000/156 | Cost: 0.1709
# Epoch: 063/100 | Batch 120/156 | Cost: 0.2082
# Epoch: 063/100 Train Acc.: 93.18% | Validation Acc.: 84.92%
# Time elapsed: 141.66 min
# Epoch: 064/100 | Batch 000/156 | Cost: 0.2086
# Epoch: 064/100 | Batch 120/156 | Cost: 0.1597
# Epoch: 064/100 Train Acc.: 92.74% | Validation Acc.: 85.16%
# Time elapsed: 143.92 min
# Epoch: 065/100 | Batch 000/156 | Cost: 0.1616
# Epoch: 065/100 | Batch 120/156 | Cost: 0.1144
# Epoch: 065/100 Train Acc.: 92.82% | Validation Acc.: 85.60%
# Time elapsed: 146.18 min
# Epoch: 066/100 | Batch 000/156 | Cost: 0.1300
# Epoch: 066/100 | Batch 120/156 | Cost: 0.1158
# Epoch: 066/100 Train Acc.: 91.06% | Validation Acc.: 83.72%
# Time elapsed: 148.42 min
# Epoch: 067/100 | Batch 000/156 | Cost: 0.2079
# Epoch: 067/100 | Batch 120/156 | Cost: 0.1398
# Epoch: 067/100 Train Acc.: 94.26% | Validation Acc.: 85.44%
# Time elapsed: 150.66 min
# Epoch: 068/100 | Batch 000/156 | Cost: 0.2075
# Epoch: 068/100 | Batch 120/156 | Cost: 0.1980
# Epoch: 068/100 Train Acc.: 93.32% | Validation Acc.: 83.56%
# Time elapsed: 152.90 min
# Epoch: 069/100 | Batch 000/156 | Cost: 0.1806
# Epoch: 069/100 | Batch 120/156 | Cost: 0.2446
# Epoch: 069/100 Train Acc.: 92.89% | Validation Acc.: 84.20%
# Time elapsed: 155.12 min
# Epoch: 070/100 | Batch 000/156 | Cost: 0.1682
# Epoch: 070/100 | Batch 120/156 | Cost: 0.2022
# Epoch: 070/100 Train Acc.: 92.92% | Validation Acc.: 83.64%
# Time elapsed: 157.38 min
# Epoch: 071/100 | Batch 000/156 | Cost: 0.1425
# Epoch: 071/100 | Batch 120/156 | Cost: 0.1567
# Epoch: 071/100 Train Acc.: 93.64% | Validation Acc.: 84.76%
# Time elapsed: 159.63 min
# Epoch: 072/100 | Batch 000/156 | Cost: 0.1112
# Epoch: 072/100 | Batch 120/156 | Cost: 0.1131
# Epoch: 072/100 Train Acc.: 91.56% | Validation Acc.: 85.24%
# Time elapsed: 161.88 min
# Epoch: 073/100 | Batch 000/156 | Cost: 0.2401
# Epoch: 073/100 | Batch 120/156 | Cost: 0.2086
# Epoch: 073/100 Train Acc.: 93.98% | Validation Acc.: 85.64%
# Time elapsed: 164.14 min
# Epoch: 074/100 | Batch 000/156 | Cost: 0.1848
# Epoch: 074/100 | Batch 120/156 | Cost: 0.1818
# Epoch: 074/100 Train Acc.: 94.60% | Validation Acc.: 86.68%
# Time elapsed: 166.37 min
# Epoch: 075/100 | Batch 000/156 | Cost: 0.0992
# Epoch: 075/100 | Batch 120/156 | Cost: 0.2242
# Epoch: 075/100 Train Acc.: 94.18% | Validation Acc.: 86.08%
# Time elapsed: 168.62 min
# Epoch: 076/100 | Batch 000/156 | Cost: 0.2205
# Epoch: 076/100 | Batch 120/156 | Cost: 0.1612
# Epoch: 076/100 Train Acc.: 94.34% | Validation Acc.: 86.16%
# Time elapsed: 170.87 min
# Epoch: 077/100 | Batch 000/156 | Cost: 0.1080
# Epoch: 077/100 | Batch 120/156 | Cost: 0.2000
# Epoch: 077/100 Train Acc.: 94.94% | Validation Acc.: 85.24%
# Time elapsed: 173.12 min
# Epoch: 078/100 | Batch 000/156 | Cost: 0.2148
# Epoch: 078/100 | Batch 120/156 | Cost: 0.1692
# Epoch: 078/100 Train Acc.: 95.68% | Validation Acc.: 85.72%
# Time elapsed: 175.38 min
# Epoch: 079/100 | Batch 000/156 | Cost: 0.0958
# Epoch: 079/100 | Batch 120/156 | Cost: 0.0719
# Epoch: 079/100 Train Acc.: 95.12% | Validation Acc.: 84.64%
# Time elapsed: 177.62 min
# Epoch: 080/100 | Batch 000/156 | Cost: 0.0749
# Epoch: 080/100 | Batch 120/156 | Cost: 0.0889
# Epoch: 080/100 Train Acc.: 94.36% | Validation Acc.: 84.56%
# Time elapsed: 179.88 min
# Epoch: 081/100 | Batch 000/156 | Cost: 0.1240
# Epoch: 081/100 | Batch 120/156 | Cost: 0.1117
# Epoch: 081/100 Train Acc.: 96.16% | Validation Acc.: 85.48%
# Time elapsed: 182.13 min
# Epoch: 082/100 | Batch 000/156 | Cost: 0.1884
# Epoch: 082/100 | Batch 120/156 | Cost: 0.1272
# Epoch: 082/100 Train Acc.: 95.51% | Validation Acc.: 86.16%
# Time elapsed: 184.37 min
# Epoch: 083/100 | Batch 000/156 | Cost: 0.0804
# Epoch: 083/100 | Batch 120/156 | Cost: 0.1125
# Epoch: 083/100 Train Acc.: 94.57% | Validation Acc.: 85.60%
# Time elapsed: 186.62 min
# Epoch: 084/100 | Batch 000/156 | Cost: 0.1007
# Epoch: 084/100 | Batch 120/156 | Cost: 0.0981
# Epoch: 084/100 Train Acc.: 96.04% | Validation Acc.: 86.32%
# Time elapsed: 188.88 min
# Epoch: 085/100 | Batch 000/156 | Cost: 0.0591
# Epoch: 085/100 | Batch 120/156 | Cost: 0.1098
# Epoch: 085/100 Train Acc.: 96.24% | Validation Acc.: 86.44%
# Time elapsed: 191.15 min
# Epoch: 086/100 | Batch 000/156 | Cost: 0.0969
# Epoch: 086/100 | Batch 120/156 | Cost: 0.0962
# Epoch: 086/100 Train Acc.: 95.94% | Validation Acc.: 84.60%
# Time elapsed: 193.40 min
# Epoch: 087/100 | Batch 000/156 | Cost: 0.2256
# Epoch: 087/100 | Batch 120/156 | Cost: 0.1419
# Epoch: 087/100 Train Acc.: 96.62% | Validation Acc.: 86.24%
# Time elapsed: 195.65 min
# Epoch: 088/100 | Batch 000/156 | Cost: 0.1249
# Epoch: 088/100 | Batch 120/156 | Cost: 0.0961
# Epoch: 088/100 Train Acc.: 94.39% | Validation Acc.: 85.16%
# Time elapsed: 197.88 min
# Epoch: 089/100 | Batch 000/156 | Cost: 0.1367
# Epoch: 089/100 | Batch 120/156 | Cost: 0.1330
# Epoch: 089/100 Train Acc.: 95.81% | Validation Acc.: 85.56%
# Time elapsed: 200.14 min
# Epoch: 090/100 | Batch 000/156 | Cost: 0.1245
# Epoch: 090/100 | Batch 120/156 | Cost: 0.0795
# Epoch: 090/100 Train Acc.: 95.26% | Validation Acc.: 86.64%
# Time elapsed: 202.40 min
# Epoch: 091/100 | Batch 000/156 | Cost: 0.1038
# Epoch: 091/100 | Batch 120/156 | Cost: 0.0785
# Epoch: 091/100 Train Acc.: 94.38% | Validation Acc.: 84.40%
# Time elapsed: 204.65 min
# Epoch: 092/100 | Batch 000/156 | Cost: 0.1278
# Epoch: 092/100 | Batch 120/156 | Cost: 0.0989
# Epoch: 092/100 Train Acc.: 96.75% | Validation Acc.: 86.32%
# Time elapsed: 206.92 min
# Epoch: 093/100 | Batch 000/156 | Cost: 0.1095
# Epoch: 093/100 | Batch 120/156 | Cost: 0.0945
# Epoch: 093/100 Train Acc.: 96.46% | Validation Acc.: 85.72%
# Time elapsed: 209.16 min
# Epoch: 094/100 | Batch 000/156 | Cost: 0.1538
# Epoch: 094/100 | Batch 120/156 | Cost: 0.0851
# Epoch: 094/100 Train Acc.: 95.18% | Validation Acc.: 85.12%
# Time elapsed: 211.41 min
# Epoch: 095/100 | Batch 000/156 | Cost: 0.0341
# Epoch: 095/100 | Batch 120/156 | Cost: 0.1560
# Epoch: 095/100 Train Acc.: 97.17% | Validation Acc.: 86.72%
# Time elapsed: 213.67 min
# Epoch: 096/100 | Batch 000/156 | Cost: 0.0425
# Epoch: 096/100 | Batch 120/156 | Cost: 0.0760
# Epoch: 096/100 Train Acc.: 96.62% | Validation Acc.: 85.36%
# Time elapsed: 215.95 min
# Epoch: 097/100 | Batch 000/156 | Cost: 0.0456
# Epoch: 097/100 | Batch 120/156 | Cost: 0.1234
# Epoch: 097/100 Train Acc.: 94.58% | Validation Acc.: 83.60%
# Time elapsed: 218.21 min
# Epoch: 098/100 | Batch 000/156 | Cost: 0.1816
# Epoch: 098/100 | Batch 120/156 | Cost: 0.0695
# Epoch: 098/100 Train Acc.: 97.21% | Validation Acc.: 86.92%
# Time elapsed: 220.45 min
# Epoch: 099/100 | Batch 000/156 | Cost: 0.0655
# Epoch: 099/100 | Batch 120/156 | Cost: 0.1239
# Epoch: 099/100 Train Acc.: 97.22% | Validation Acc.: 86.96%
# Time elapsed: 222.69 min
# Epoch: 100/100 | Batch 000/156 | Cost: 0.0745
# Epoch: 100/100 | Batch 120/156 | Cost: 0.0799
# Epoch: 100/100 Train Acc.: 97.35% | Validation Acc.: 87.00%
# Time elapsed: 224.95 min
# Total Training Time: 224.95 min

# %%
plt.plot(range(1, NUM_EPOCHS + 1),train_loss_lst, label = 'Training Loss')
plt.plot(range(1, NUM_EPOCHS + 1),valid_loss_lst, label = "validation Loss")
plt.legend(loc = 'upper right')
plt.ylabel('Cross Entropy')
plt.xlabel("Epoch")
plt.show()

# %%
train_acc_lst = [i.to('cpu') for i in train_acc_lst]
valid_acc_lst = [i.to('cpu') for i in valid_acc_lst]

# %%
plt.plot(range(1, NUM_EPOCHS+1), train_acc_lst, label='Training accuracy')
plt.plot(range(1, NUM_EPOCHS+1), valid_acc_lst, label='Validation accuracy')
plt.legend(loc='upper left')
plt.ylabel('Cross entropy')
plt.xlabel('Epoch')
plt.show()

# %% [markdown]
# ### Evaluation

# %%
model.eval()
with torch.set_grad_enabled(False): # save memery during inference
    test_acc, test_loss = compute_accuracy_and_loss(model, test_loader)
    print(f"Test accuracy: {test_acc:.2f}%")

# %%
class UnNormalized(object):
    def __init__(self, mean, std):
        self.mean = mean
        self.std = std
        
    def __call__(self, tensor):
        """
        Args:
            tensor (Tensor): Tensor image of size (C, H, W) to be normalized.
        Returns:
            Tensor: Normalized image.
        """
        
        for t,m,s in zip(tensor, self.mean, self.std):
            t.mul_(s).add_(m)
            # the normalized code t.sub_(m).div_(s)
        return tensor
    
unorm = UnNormalized(mean = train_mean, std = train_std)

# %%
test_loader = DataLoader(dataset = train_dataset,
                        batch_size = BATCH_SIZE,
                        shuffle = True)

for features, targets in test_loader:
    break
    
_, predictions = model.forward(features[:8].to(DEVICE))
predictions = torch.argmax(predictions, dim = 1)

d = {0: 'cat',
    1: 'dog'}

fig,ax = plt.subplots(1,8, figsize = (20,20))
for i in range(8):
    img = unorm(features[i])
    ax[i].imshow(np.transpose(img, (1,2,0)))
    ax[i].set_xlabel(d[predictions[i].item()])
    
plt.show()

# %%
predictions
# Out:
# tensor([1, 1, 0, 0, 1, 1, 0, 0], device='cuda:0')
